# %% [markdown]
# # Introduction to R Programming: Loops, Conditionals, & Functions
#
# Matthew D. Turner, PhD
# Georgia State University
#
# Some rights reserved: [cc by-nc-sa](https://creativecommons.org/licenses/by-nc-sa/4.0/) See bottom of document for details.
# ***
# # Statistical Examples of Loops
# This notebook contains some examples of using loops with statistical problems.
#
# ## 1. Multiple Plots
# Often when confronted with new data, the first thing you want to do is make a set of plots. There are some built-in R functions that do this, but you may need to make plots of different types.

# %%
data(mtcars)
names(mtcars)
# Out:
#  [1] "mpg"  "cyl"  "disp" "hp"   "drat" "wt"   "qsec" "vs"   "am"   "gear"
# [11] "carb"

# %%
summary(mtcars[1:4])
head(mtcars[1:4])
dim(mtcars[1:4])
# Out:
#       mpg             cyl             disp             hp
#  Min.   :10.40   Min.   :4.000   Min.   : 71.1   Min.   : 52.0
#  1st Qu.:15.43   1st Qu.:4.000   1st Qu.:120.8   1st Qu.: 96.5
#  Median :19.20   Median :6.000   Median :196.3   Median :123.0
#  Mean   :20.09   Mean   :6.188   Mean   :230.7   Mean   :146.7
#  3rd Qu.:22.80   3rd Qu.:8.000   3rd Qu.:326.0   3rd Qu.:180.0
#  Max.   :33.90   Max.   :8.000   Max.   :472.0   Max.   :335.0
#                   mpg  cyl disp hp
# Mazda RX4         21.0 6   160  110
# Mazda RX4 Wag     21.0 6   160  110
# Datsun 710        22.8 4   108   93
# Hornet 4 Drive    21.4 6   258  110
# Hornet Sportabout 18.7 8   360  175
# Valiant           18.1 6   225  105
# [1] 32  4

# %%
plot(mtcars[1:4])
# Out:
# plot without title
